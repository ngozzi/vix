# %% [markdown]
# <center>
# <h1>
#     VIX Index - Historical Prices
# </h1>
# </center>

# %%
# %pylab inline
import datetime
import pandas as pd
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Import data:

# %%
df = pd.read_csv('../data/vix_hist.csv', sep = ',')
df.head()
# Out:
#        Date  VIX Open  VIX High  VIX Low  VIX Close
# 0  1/2/2004     17.96     18.68    17.54      18.22
# 1  1/5/2004     18.45     18.49    17.44      17.49
# 2  1/6/2004     17.66     17.67    16.19      16.73
# 3  1/7/2004     16.72     16.75    15.50      15.50
# 4  1/8/2004     15.42     15.68    15.32      15.61

# %% [markdown]
# Plot all Highest prices:

# %%
n = len(df)
df['VIX High'].plot(figsize = (16,9), color = 'royalblue', title = 'VIX')
plt.xticks([i for i in np.arange(0,n,108)], [df.Date[i] for i in np.arange(0,n,108)], rotation=70);

# %% [markdown]
# Focus on the beginning of 2018 when the VIX spiked suddenly over 40 points:

# %%
df['VIX High'][n-50:n].plot(figsize = (16,9), color = 'royalblue', title = 'VIX')
plt.xticks([i for i in np.arange(n-50,n,5)], [df.Date[i] for i in np.arange(n-50,n,5)], rotation=70);
